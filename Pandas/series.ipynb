# %% [markdown]
# ### Pandas Series
#
# A Series is one-dimensional labeled array capable of holding any data type. The axis label are collectively called Index

# %% [markdown]
# ### Creating Series
#
#
# There are multiple ways to create series:

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c','d']
my_list=[10,20,30]
arr=np.array([1,2,3,4])
d={'a':10,'b':20,'c':40}

# %%
pd.Series(arr,labels)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    40
# dtype: int64

# %% [markdown]
# #### Multiple series contained together is data frame
