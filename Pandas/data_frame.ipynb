# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### **Creating a Data Frame**

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list=[
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 72000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London',85000]
]
cols=['name','age','city','salary']

df2=pd.DataFrame(data_list,columns=cols)
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   72000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #### **Selection and Indexing of column**

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   72000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[['name','age']]
# Out:
#     name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# #### **Creating new column**

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   72000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['designation']=['AI engg','Data scientist','Web devloper','SDE']
df2
# Out:
#     name  age      city  salary     designation
# 0   John   28  New York   65000         AI engg
# 1   Anna   34     Paris   72000  Data scientist
# 2  Peter   29    Berlin   62000    Web devloper
# 3  Linda   42    London   85000             SDE

# %% [markdown]
# #### **Removing columns**

# %%
df2.drop('designation',axis=1,inplace=True)
#inplace=true:-  changes the original data frame in memory
# if not mentioned then inplace is false and virtual copy of changed data frame is provided

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   72000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(['city','salary'],axis=1)
# Out:
#     name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# #### **Selecting Rows**

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   72000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]]
# Out:
#    name  age      city  salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   72000

# %%
df2.iloc[3]
# Out:
# name       Linda
# age           42
# city      London
# salary     85000
# Name: 3, dtype: object

# %% [markdown]
# #### **Selecting Subsets of rows and columns**

# %%
df2.loc[[0,1]][['city','salary']]
# Out:
#        city  salary
# 0  New York   65000
# 1     Paris   72000

# %%
df2.loc[[2,3]][['name','age']]
# Out:
#     name  age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# #### **Conditional Selection**

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   72000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#age above 30
df2[df2['age']>30]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   72000
# 3  Linda   42  London   85000

# %%
#age above 30 and from paris
df2[(df2['city']=='Paris') & (df2['age']>30)]
# Out:
#    name  age   city  salary
# 1  Anna   34  Paris   72000
