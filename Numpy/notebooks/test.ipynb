# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------- ----------------------------- 3.4/12.4 MB 18.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.4 MB 13.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.4 MB 10.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.4 MB 10.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.4 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.4 MB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.4 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 7.5 MB/s  0:00:01
# ...

# %%
import numpy as np

# %% [markdown]
# <bold>Basic Array Creation</bold>
